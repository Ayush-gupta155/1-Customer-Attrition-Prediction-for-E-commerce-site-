# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
read_xlsx = pd.read_excel("E Commerce Dataset.xlsx",sheet_name='E Comm')
df = pd.DataFrame(pd.read_excel("E Commerce Dataset.xlsx",sheet_name='E Comm'))
# read_xlsx.to_csv("E Commerce Dataset.csv",index = None,header=True)
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %%
df.head(10)
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
# 5       50006      1     0.0             Computer         1             22.0
# 6       50007      1     NaN                Phone         3             11.0
# 7       50008      1     NaN                Phone         1              6.0
# 8       50009      1    13.0                Phone         3              9.0
# 9       50010      1     NaN                Phone         1             31.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
read_xlsx.to_csv("E Commerce Dataset.csv",index = None,header=True)
df = pd.DataFrame(pd.read_csv("E Commerce Dataset.csv"))

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
for i in df.columns:
    percent = round(df[i].isna().sum()*100/len(df[i]),2)
    print(f'''Coloumn {i}:''')
    print('Missing values :',df[i].isna().sum(),'from ',len(df))
    print(f'''Percent missing value:''',percent, '%')
    print('---'*10)
# Out:
# Coloumn CustomerID:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn Churn:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn Tenure:
# Missing values : 264 from  5630
# Percent missing value: 4.69 %
# ------------------------------
# Coloumn PreferredLoginDevice:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn CityTier:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn WarehouseToHome:
# Missing values : 251 from  5630
# Percent missing value: 4.46 %
# ------------------------------
# Coloumn PreferredPaymentMode:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn Gender:
# Missing values : 0 from  5630
# Percent missing value: 0.0 %
# ------------------------------
# Coloumn HourSpendOnApp:
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %% [markdown]
# ## Numerical Features

# %%
num_fea = [features for features in df.columns if df[features].dtype != 'O']
num_fea
# Out:
# ['CustomerID',
#  'Churn',
#  'Tenure',
#  'CityTier',
#  'WarehouseToHome',
#  'HourSpendOnApp',
#  'NumberOfDeviceRegistered',
#  'SatisfactionScore',
#  'NumberOfAddress',
#  'Complain',
#  'OrderAmountHikeFromlastYear',
#  'CouponUsed',
#  'OrderCount',
#  'DaySinceLastOrder',
#  'CashbackAmount']

# %%
df[num_fea].describe().transpose()
# Out:
#                               count          mean          std      min  \
# CustomerID                   5630.0  52815.500000  1625.385339  50001.0
# Churn                        5630.0      0.168384     0.374240      0.0
# Tenure                       5366.0     10.189899     8.557241      0.0
# CityTier                     5630.0      1.654707     0.915389      1.0
# WarehouseToHome              5379.0     15.639896     8.531475      5.0
# HourSpendOnApp               5375.0      2.931535     0.721926      0.0
# NumberOfDeviceRegistered     5630.0      3.688988     1.023999      1.0
# SatisfactionScore            5630.0      3.066785     1.380194      1.0
# NumberOfAddress              5630.0      4.214032     2.583586      1.0
# Complain                     5630.0      0.284902     0.451408      0.0
# OrderAmountHikeFromlastYear  5365.0     15.707922     3.675485     11.0
# CouponUsed                   5374.0      1.751023     1.894621      0.0
# ...

# %% [markdown]
# ## Categorical Features

# %%
cat_fea = [features for features in df.columns if df[features].dtype == 'O']
cat_fea
# Out:
# ['PreferredLoginDevice',
#  'PreferredPaymentMode',
#  'Gender',
#  'PreferedOrderCat',
#  'MaritalStatus']

# %%
df[cat_fea].describe()
# Out:
#        PreferredLoginDevice PreferredPaymentMode Gender    PreferedOrderCat  \
# count                  5630                 5630   5630                5630
# unique                    3                    7      2                   6
# top            Mobile Phone           Debit Card   Male  Laptop & Accessory
# freq                   2765                 2314   3384                2050
#
#        MaritalStatus
# count           5630
# unique             3
# top          Married
# freq            2986

# %%
for features in cat_fea:
    print(" The feature is '{}'. Number of categories are: {}".format(features,len(df[features].unique())))
# Out:
#  The feature is 'PreferredLoginDevice'. Number of categories are: 3
#  The feature is 'PreferredPaymentMode'. Number of categories are: 7
#  The feature is 'Gender'. Number of categories are: 2
#  The feature is 'PreferedOrderCat'. Number of categories are: 6
#  The feature is 'MaritalStatus'. Number of categories are: 3

# %%
for features in cat_fea:
    print(" '{}' has {} unique values".format(features,df[features].unique()))
# Out:
#  'PreferredLoginDevice' has ['Mobile Phone' 'Phone' 'Computer'] unique values
#  'PreferredPaymentMode' has ['Debit Card' 'UPI' 'CC' 'Cash on Delivery' 'E wallet' 'COD' 'Credit Card'] unique values
#  'Gender' has ['Female' 'Male'] unique values
#  'PreferedOrderCat' has ['Laptop & Accessory' 'Mobile' 'Mobile Phone' 'Others' 'Fashion' 'Grocery'] unique values
#  'MaritalStatus' has ['Single' 'Divorced' 'Married'] unique values

# %%
# Seeing the numerical variable count value

for col in num_fea:
    percent = round(df[col].value_counts()*100/len(df[col]),2)
    print(f'''Value count Column {col}:''')
    print(df[col].value_counts())
    print('')
    print('Percentage :\n',percent)
    print('---'*10)
    print()
# Out:
# Value count Column CustomerID:
# 50001    1
# 53751    1
# 53759    1
# 53758    1
# 53757    1
#         ..
# 51876    1
# 51875    1
# 51874    1
# 51873    1
# 55630    1
# Name: CustomerID, Length: 5630, dtype: int64
#
# Percentage :
#  50001    0.02
# 53751    0.02
# 53759    0.02
# 53758    0.02
# 53757    0.02
#          ...
# 51876    0.02
# 51875    0.02
# 51874    0.02
# 51873    0.02
# 55630    0.02
# Name: CustomerID, Length: 5630, dtype: float64
# ------------------------------
#
# Value count Column Churn:
# 0    4682
# 1     948
# Name: Churn, dtype: int64
#
# Percentage :
#  0    83.16
# 1    16.84
# Name: Churn, dtype: float64
# ------------------------------
#
# Value count Column Tenure:
# 1.0     690
# 0.0     508
# 8.0     263
# 9.0     247
# 7.0     221
# 10.0    213
# 5.0     204
# 4.0     203
# 3.0     195
# 11.0    194
# 6.0     183
# 12.0    182
# 13.0    181
# 14.0    176
# 2.0     167
# 15.0    159
# 16.0    149
# 19.0    140
# 18.0    123
# 20.0    109
# ...

# %%
# Looking for value count categorical variables 
for col in cat_fea:
    percent = round(df[col].value_counts()*100/len(df[col]),2)
    print(f'''Value count Columns {col}:''')
    print(df[col].value_counts())
    print('')
    print('Percentage :\n',percent)
    print('---'*10)
    print()
# Out:
# Value count Columns PreferredLoginDevice:
# Mobile Phone    2765
# Computer        1634
# Phone           1231
# Name: PreferredLoginDevice, dtype: int64
#
# Percentage :
#  Mobile Phone    49.11
# Computer        29.02
# Phone           21.87
# Name: PreferredLoginDevice, dtype: float64
# ------------------------------
#
# Value count Columns PreferredPaymentMode:
# Debit Card          2314
# Credit Card         1501
# E wallet             614
# UPI                  414
# COD                  365
# CC                   273
# Cash on Delivery     149
# Name: PreferredPaymentMode, dtype: int64
#
# Percentage :
#  Debit Card          41.10
# Credit Card         26.66
# E wallet            10.91
# UPI                  7.35
# COD                  6.48
# CC                   4.85
# Cash on Delivery     2.65
# Name: PreferredPaymentMode, dtype: float64
# ------------------------------
#
# Value count Columns Gender:
# Male      3384
# Female    2246
# Name: Gender, dtype: int64
#
# ...

# %%
# # Change Phone -> Mobile Phone to remove data redundancy
# df['PreferredLoginDevice'] = df['PreferredLoginDevice'].replace({'Phone' : 'Mobile Phone'})

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Making boxplot diagrams
plt.figure(figsize=(18,4))

for i in range (0, len(num_fea)):
    plt.subplot(1, len(num_fea), i+1)
    sns.boxplot(y=df[num_fea[i]], color='#2ecc71', orient='v')
    plt.tight_layout(pad = 2)

# %% [markdown]
# The results obtained in the diagram above are normally distributed features such as CustomerID, CityTier, HourSpendOnApp, NumberOfDeviceRegistered, SatisfactionScore, Complain and CashbackAmount.
#
# There are also outliers that need further pre-processing.

# %%
# Create a kde-plot diagram to see the distribution of data
plt.figure(figsize=(20, 5))
for i in range(0, len(num_fea)):
    plt.subplot(2, 8, i+1)
    sns.distplot(df[num_fea[i]], color='blue')
    plt.tight_layout(pad = 1.5)
# Out:
# C:\Users\AYUSH GUPTA\anaconda3-NEW\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AYUSH GUPTA\anaconda3-NEW\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# From the diagram above, there is a positive skew distribution marked with the Mean > Median value. There are several features that are of concern such as Tenure, CouponUsed, DaySinceLastOrder, CashbackAmount

# %%
# KDE plot highlighting the 'Churn' as the target variable
plt.figure(figsize=(24, 5))
for i in range(0, len(num_fea)):
    plt.subplot(2, 8, i+1)
    sns.histplot(data=df, x=df[num_fea[i]], hue="Churn", kde="True")
    plt.tight_layout(pad = 2)

# %% [markdown]
# The average customer spends 3 hours using e-commerce applications.
#
# There are still many customers who do not use coupons in shopping.
#
# Customers with locations closer to the warehouse (< 15 km) predominate.
#
# The number of customers who complained was quite a lot around 1000 people. This should be a concern in future business development.
#
# By highlighting Churn as the target variable, you can see the distribution of customer data which is churn. From the diagram above it can be seen the proportion of customers who churn for each feature.
#
# Tenure variable is a concern because there are many customers who churn on tenure < 3 months.

# %%
# Violin plot
plt.figure(figsize=(20, 5))
for i in range(0, len(num_fea)):
    plt.subplot(2, 8, i+1)
    sns.violinplot(y=df[num_fea[i]], color='lightblue', orient='v')
    plt.tight_layout(pad=2)

# %% [markdown]
# **Observation Results 🔽**
#
# The violinplot diagram can better show the concentration of data distribution than the boxplot diagram.
#
# The portion of churned customers is quite large. When seen from the results of the previous descriptive analysis, it was 16.84% of the total customers.

# %%
# Countplot to see the distribution of the categorical variables
plt.figure(figsize=(16,10))
for i in range (0, len(cat_fea[0:])):
    plt.subplot(2, 3, i+1)
    sns.countplot(df[cat_fea[0:][i]], color='lightskyblue', orient='h')
    plt.tick_params(axis='x', rotation=90)
    plt.tight_layout(pad=2)
# Out:
# C:\Users\AYUSH GUPTA\anaconda3-NEW\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AYUSH GUPTA\anaconda3-NEW\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AYUSH GUPTA\anaconda3-NEW\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# **Observation Results 🔽**
#
# Nearly 50% of customers are dominated by customers who transact via mobile phone applications. The Debit Card payment method is preferred by customers. Customers are more dominated by men than women. This can be seen in the sales of the Laptop & Accessory category which outperformed the fashion category.
#
# In the PreferredPaymentMode variable there is an ambiguous value between Cash On Delivery and COD. In our opinion, further pre-processing is needed.

# %%
# Countplot highlighting "Churn" as target variable
plt.figure(figsize=(16,10))
for i in range (0, len(cat_fea[0:])):
    plt.subplot(2, 3, i+1)
    sns.countplot(data=df, x=df[cat_fea[0:][i]], hue='Churn', orient='h')
    plt.tick_params(axis='x', rotation=90)
    plt.tight_layout(pad=2)

# %% [markdown]
# **Observation Results 🔽**
#
# The spread of churn customers is still very small compared to customers who do not churn. It is necessary to analyze the correlation between numerical & categorical variables to see which variables affect the churn rate.

# %% [markdown]
# ## Multivariate Analysis

# %%
# Correlation Heatmap (Numeric)
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), cmap='crest', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation Results
#
# From the heatmap above, it can be obtained that there is a feature correlation with the target, where the target is churn. The feature that has a high correlation with the churn target is Tenure -0.35. This includes a negative correlation, meaning that the greater the tenure value, the lower the churn rate. In addition, the correlation of other features is quite large, namely between churn and complaints of 0.25. Where this includes a positive correlation, meaning that the greater the value of the complaint, the greater the churn rate. Thus, features that are relevant and must be maintained are tenure and complain features.

# %% [markdown]
# # Pair Plots (Numeric)
# sns.pairplot(df, diag_kind='kde', hue='Churn')

# %% [markdown]
# **Observation Results**
#
# From the pair plots above, the scatter plot separation does not look good enough, so it is quite difficult to get an accurate feature correlation.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='Tenure', y = num_fea[i], hue='Churn', size=6, alpha=0.1)
  plt.tick_params(axis='x', rotation=60)
  plt.tight_layout()

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='CityTier', y=num_fea[i], hue='Churn', size=8, alpha=0.1)
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
# It can be seen that the correlation of the CityTier category with all numerical values ​​has no effect, because the stripplot shows an average.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='PreferredLoginDevice', y=num_fea[i])
  plt.tight_layout()

# %% [markdown]
# Observation Results
#
# It can be seen that the correlation of the PreferredLoginDevice category with all numerical values ​​has no effect, because the stripplot looks flat.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='WarehouseToHome', y=num_fea[i])
  plt.tick_params(axis='x', rotation=60)
  plt.tight_layout()

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='PreferredLoginDevice', y=num_fea[i])
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
# It can be seen that the correlation of the preferred login device category with all numericals has no effect, because the stripplot shows an average. However, there are two correlations between the cashback ampount and Coupon Used features with the preferred login device, namely those who use fewer phones than the others.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(20,20))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='PreferredPaymentMode', y=num_fea[i])
  plt.tick_params(axis='x', rotation=45)
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
# It can be seen that the correlation of the preferred payment method category with all numerical ones has no effect, because the stripplot shows an average.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='Gender', y=num_fea[i])
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
#  It can be seen that there is no significant correlation between gender categories and all numerical categories, because the stripplot shows an average level.

# %%
#Category Plots (Categorical-Numeric) 
fig = plt.figure(figsize=(20,20))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='PreferedOrderCat', y=num_fea[i])
  plt.tick_params(axis='x', rotation=45)
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
# The correlation of Cat's preferred order category with all numerical can be seen that there is an interesting pattern in the cashback amount feature, this is because each cat's prefred order has a varying cashback amount value

# %%
#Category Plots (Categorical-Numeric) Categorical = 
fig = plt.figure(figsize=(15,15))
for i in range(0,len(num_fea[0:])):
  ax = fig.add_subplot(5, 3, i+1)
  sns.stripplot(ax=ax, data=df, x='MaritalStatus', y=num_fea[i])
  plt.tight_layout()

# %% [markdown]
# **Observation Results**
#
# It can be seen that the correlation of the Marital Status category with all numerical values ​​has no effect, because the stripplot shows an average.

# %% [markdown]
# ## Business Insight

# %% [markdown]
# ### Tenure

# %%
# plt.figure(figsize=(20,8))
tenure_churn = pd.crosstab(df["Tenure"], df["Churn"])
tenure_churn.plot(kind = 'bar', stacked = 'true', title = "Churn by Tenure",figsize = (20,8))
tenure_churn
# fig = plt.figure()
 
# fig.set_figheight(5)
# # fig.set_figwidth(10)
# fig.set_figwidth(10)

plt.xlabel('Tenure')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# Based on graphic data, it can be indicated that most of the customers who do churn come from customers with a tenure of less than 2, or are classified as new customers.

# %%
payment = df.groupby(['PreferredPaymentMode','Churn']).nunique('customerID').reset_index()
fig, ax =  plt.subplots(1,1,figsize=(10,7))
bar = sns.barplot(x="PreferredPaymentMode", y="CustomerID", data=payment, hue="Churn")
plt.xlabel('Payment method')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 90)
plt.title('Churn Based on Payment Method', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Churn Based on Payment Method')

# %%
new_df = df.groupby('PreferredPaymentMode')['Churn'].value_counts(normalize=True)
new_df = new_df.mul(100).rename('Percent').reset_index()
g = sns.catplot(x='PreferredPaymentMode', y='Percent', hue='Churn', kind='bar', data=new_df)
for p in g.ax.patches:
    txt = str(p.get_height().round(1)) + '%'
    txt_x = p.get_x()
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)
g.ax.set_ylim(0,100)
plt.xlabel('Payment method')
plt.ylabel('Percentage')
plt.xticks(rotation = 45)
plt.title('Churn Based on Payment Method', fontsize=15)
plt.figure(figsize=(25, 10))

# %% [markdown]
# From the graph above it can be seen that the payment method that the customer uses has no significant effect on the possibility of the customer churning.

# %% [markdown]
# ## Gender

# %%
gender = df.groupby(['Gender','Churn']).nunique('customerID').reset_index()
fig, ax =  plt.subplots(1,1,figsize=(5,6))
bar = sns.barplot(x="Gender", y="CustomerID", data=gender, hue="Churn")
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.title('Churn by Gender', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Churn by Gender')

# %%
new_df = df.groupby('Gender')['Churn'].value_counts(normalize=True)
new_df = new_df.mul(100).rename('Percent').reset_index()
g = sns.catplot(x='Gender', y='Percent', hue='Churn', kind='bar', data=new_df)
for p in g.ax.patches:
    txt = str(p.get_height().round(1)) + '%'
    txt_x = p.get_x()
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)
g.ax.set_ylim(0,100)
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.title('Churn by Gender', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Churn by Gender')

# %% [markdown]
# The graph shows that crunches are not affected by customer gender.

# %% [markdown]
# ### Hour spend on App

# %%
hour = df.groupby(['HourSpendOnApp','Churn']).nunique('customerID').reset_index()
fig, ax =  plt.subplots(1,1,figsize=(5,6))
bar = sns.barplot(x="HourSpendOnApp", y="CustomerID", data=hour, hue="Churn")
plt.xlabel('Spent Hours')
plt.ylabel('Jumlah Customer')
plt.title('Churn based on Spent Hours', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Churn based on Spent Hours')

# %%
new_df = df.groupby('HourSpendOnApp')['Churn'].value_counts(normalize=True)
new_df = new_df.mul(100).rename('Percent').reset_index()
g = sns.catplot(x='HourSpendOnApp', y='Percent', hue='Churn', kind='bar', data=new_df)
for p in g.ax.patches:
    txt = str(p.get_height().round(1)) + '%'
    txt_x = p.get_x()
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)
g.ax.set_ylim(0,100)
plt.xlabel('Spent Hours')
plt.ylabel('Percentage')
plt.title('Churn Based on Spent Hours', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Churn Based on Spent Hours')
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# The graph obtained shows that the amount of time spent by the customers in using the application or accessing the website has no correlation with the potential of those customers to churn.

# %% [markdown]
# #### Number of Device Registered

# %%
device = df.groupby(['NumberOfDeviceRegistered','Churn']).nunique('customerID').reset_index()
fig, ax =  plt.subplots(1,1,figsize=(6,7))
bar = sns.barplot(x="NumberOfDeviceRegistered", y="CustomerID", data=device, hue="Churn")
plt.xlabel('No of Device')
plt.ylabel('No of Customer')
plt.title('Devices based on Churn', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Devices based on Churn')

# %%
new_df = df.groupby('NumberOfDeviceRegistered')['Churn'].value_counts(normalize=True)
new_df = new_df.mul(100).rename('Percent').reset_index()
g = sns.catplot(x='NumberOfDeviceRegistered', y='Percent', hue='Churn', kind='bar', data=new_df)
for p in g.ax.patches:
    txt = str(p.get_height().round(1)) + '%'
    txt_x = p.get_x()
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)
g.ax.set_ylim(0,100)
plt.xlabel('No of Device')
plt.ylabel('Percentage')
plt.title('Devices based on Churn', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Devices based on Churn')

# %% [markdown]
# From the graph it can be deduced that the more devices a customer owns, the higher the customer churn rate.

# %% [markdown]
# #### Prefered Order Category

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='PreferedOrderCat', data=df, hue='Churn')
plt.xticks(rotation = 0)
plt.title('Churn Based on Preferred Order Category')
# Out:
# Text(0.5, 1.0, 'Churn Based on Preferred Order Category')

# %% [markdown]
# ### Satisfaction Score

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='SatisfactionScore', data=df, hue='Churn')
plt.title('Churn based on Satisfaction Score')
# Out:
# Text(0.5, 1.0, 'Churn based on Satisfaction Score')

# %% [markdown]
# Going by the graph above, Satisfaction Score 3, 4, 5 is still experiencing churn.

# %% [markdown]
# ### Marital Status

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='MaritalStatus', data=df, hue='Churn')
plt.title('Churn based on Marital Status')
# Out:
# Text(0.5, 1.0, 'Churn based on Marital Status')

# %% [markdown]
# Based on the graph above, customers who are still single experienced a lot of churn, while customers who were divorced experienced little churn.

# %% [markdown]
# ### Number Of Address

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='NumberOfAddress', data=df, hue='Churn')
plt.title('Churn Based on Number Of Address')
# Out:
# Text(0.5, 1.0, 'Churn Based on Number Of Address')

# %% [markdown]
# Based on the graph above, the Number Of Addresses that churn a lot are 2 and 3.

# %% [markdown]
# ## Complain

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Complain', data=df, hue='Churn')
plt.title('Churn Based on Complain')
# Out:
# Text(0.5, 1.0, 'Churn Based on Complain')

# %% [markdown]
# Based on the graph above, customers who complain experience a lot of churn compared to those who don't

# %% [markdown]
# ### Order Amount Hike from Last Year

# %%
OAH_churn = pd.crosstab(df["OrderAmountHikeFromlastYear"], df["Churn"])
OAH_churn.plot(kind = 'bar', stacked = 'true', title = "Churn Based on Order Amount Hike",figsize = (10,5))
OAH_churn
plt.xlabel('% Order Amount Hike')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# Based on the chart, the lower the percentage increase in orders from last year, especially in the 11-15 range, the higher the churn rate. However, the range above 16-25 is less significant because for every percentage there are always customers who churnm

# %% [markdown]
# ### Coupon Used

# %%
CU_churn = pd.crosstab(df["CouponUsed"], df["Churn"])
CU_churn.plot(kind = 'bar', stacked = 'true', title = "Churn Based on of Used Coupon",figsize = (10,5))
CU_churn
plt.xlabel('Used Coupon')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 0)
plt.figure(figsize=(25, 25))
plt.show()

# %% [markdown]
# In the graph above, it can be seen that the level of customer churn is higher for customers who use a few coupons (1-2 only) even by customers who don't use coupons at all.

# %% [markdown]
# ### Order Count

# %%
OC_churn = pd.crosstab(df["OrderCount"], df["Churn"])
OC_churn.plot(kind = 'bar', stacked = 'true', title = "Churn based on Order Count",figsize = (10,5))
OC_churn
plt.xlabel('# Order Count')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# From the graph above, it can be seen that customers who only order 1-2 times tend to churn. It is possible that this type of customer is just trying and doesn't feel right or is called a one time buyer.

# %%
DLO_churn = pd.crosstab(df["DaySinceLastOrder"], df["Churn"])
DLO_churn.plot(kind = 'bar', stacked = 'true', title = "Churn based on Day Since Last Order",figsize = (13,5))
DLO_churn
plt.xlabel('Days Since Last Order')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# From the graph above, customers who tend to churn are customers who have recently placed an order. This is possible because there are customers who feel disappointed with the transactions made

# %% [markdown]
# ### Cashback Amount

# %%
dfCA = df
dfCA['CashbackAmountGroup'] = np.where(dfCA['CashbackAmount']<125,'Low',
                                      np.where(dfCA['CashbackAmount']<175, 'Medium', 'High'))
dfCA.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  ...  \
# 0           Debit Card  Female             3.0                         3  ...
# 1                  UPI    Male             3.0                         4  ...
# 2           Debit Card    Male             2.0                         4  ...
# 3           Debit Card    Male             2.0                         4  ...
# 4                   CC    Male             NaN                         3  ...
#
# ...

# %%
DLO_CA = pd.crosstab(dfCA["CashbackAmountGroup"], dfCA["Churn"])
DLO_CA.plot(kind = 'bar', stacked = 'true', title = "Churn based on Cashback Amount",figsize = (13,5))
DLO_CA
plt.xlabel('Cashback Amount Type')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# In this graph, users are grouped based on the amount of cashback earned. We determine that customers who get less than 125 cashback are categorized as "Low", 125-175 are categorized as 'Medium", and more than 175 are considered high.
#
# In the graph data, there is no significant difference between the number of customers who churn and the total cashback received. This is also in line with the heatmap that the correlation between the amount of cashback earned and customers who churn is not significantly correlated
